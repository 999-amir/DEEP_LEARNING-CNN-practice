# %% [markdown]
# <div class="text-info">
#     <div class="text-center">
#         <div class="h2">season 4 - project 3 - yolo [object detection]</div>
#         <div class="h3">maktabkhooneh - <span class="text-danger">deep learning</span></div>
#     </div>
#     <div class="h4">Name: Amir Mohammad Arghavany</div>
#     <div class="h4">Email: amir.arghavoon@gmail.com</div>
# </div>

# %% [markdown]
# # install dependence

# %%
# pip install torch
# conda install git
# git clone https://github.com/ultralytics/yolov5
# !pip install -r yolov5/requirements.txt

# %% [markdown]
# # camera object detection

# %%
# !python yolov5/detect.py --source 0

# %% [markdown]
# # video object detection

# %%
# !python yolov5/detect.py --weights yolov5x.pt --source video_name.mp4 --view-img

# %% [markdown]
# # image detection

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# add image in jupyter file directory
image_name = 'car.jpg'

# %%
# convert image to array
img1 = cv2.imread(image_name)

# %%
# show image from array
plt.imshow(img1).figure.set_size_inches(10, 10)

# %%
# detect image with accuracy [up to 80%]
output = !python yolov5/detect.py --weights yolov5x.pt --source car.jpg --conf-thres 0.8

# %%
# get directory of saved image
directory = f'yolov5/runs/detect/{output[-1:][0].split('\\')[-1:][0][:-4]}/{image_name}'
print('image saved in ->', directory)
# Out:
# image saved in -> yolov5/runs/detect/exp2/car.jpg

# %%
img2 = cv2.imread(directory)

# %%
# show image from array
plt.imshow(img2).figure.set_size_inches(10, 10)
